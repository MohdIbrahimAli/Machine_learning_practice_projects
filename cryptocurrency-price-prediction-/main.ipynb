# %% [markdown]
# # CryptoCurrency Price prediction for 30 days

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.0-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from yfinance) (2.4.0)
# Collecting requests>=2.31 (from yfinance)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.19.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting cffi>=1.12.0 (from curl_cffi<0.14,>=0.7->yfinance)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi<0.14,>=0.7->yfinance)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached soupsieve-2.8.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\ibrahim\machine_learning_practice_projects\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Downloading yfinance-1.0-py2.py3-none-any.whl (127 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 2.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.4 MB/s  0:00:00
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading peewee-3.19.0-py3-none-any.whl (411 kB)
# Using cached protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached soupsieve-2.8.1-py3-none-any.whl (36 kB)
# Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=c0edc287e8470fe9ba7a5590c76a0f7d30cbe2dd027d9df636b00ce8011bd60a
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\cc\bd\6f\664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
# Successfully built multitasking
# Installing collected packages: peewee, multitasking, websockets, urllib3, soupsieve, pycparser, protobuf, idna, frozendict, charset_normalizer, certifi, requests, cffi, beautifulsoup4, curl_cffi, yfinance
#
#    ----------------------------------------  0/16 [peewee]
#    ----------------------------------------  0/16 [peewee]
#    ----------------------------------------  0/16 [peewee]
#    ----------------------------------------  0/16 [peewee]
#    ----------------------------------------  0/16 [peewee]
#    ----------------------------------------  0/16 [peewee]
#    ----------------------------------------  0/16 [peewee]
#    ----------------------------------------  0/16 [peewee]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ----- ----------------------------------  2/16 [websockets]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ------- --------------------------------  3/16 [urllib3]
#    ---------- -----------------------------  4/16 [soupsieve]
#    ---------- -----------------------------  4/16 [soupsieve]
#    ---------- -----------------------------  4/16 [soupsieve]
#    ------------ ---------------------------  5/16 [pycparser]
#    ------------ ---------------------------  5/16 [pycparser]
#    ------------ ---------------------------  5/16 [pycparser]
#    ------------ ---------------------------  5/16 [pycparser]
#    ------------ ---------------------------  5/16 [pycparser]
#    ------------ ---------------------------  5/16 [pycparser]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    --------------- ------------------------  6/16 [protobuf]
#    ----------------- ----------------------  7/16 [idna]
#    ----------------- ----------------------  7/16 [idna]
#    ----------------- ----------------------  7/16 [idna]
#    -------------------- -------------------  8/16 [frozendict]
#    ---------------------- -----------------  9/16 [charset_normalizer]
#    ---------------------- -----------------  9/16 [charset_normalizer]
#    ---------------------- -----------------  9/16 [charset_normalizer]
#    ---------------------- -----------------  9/16 [charset_normalizer]
#    ------------------------- -------------- 10/16 [certifi]
#    --------------------------- ------------ 11/16 [requests]
#    --------------------------- ------------ 11/16 [requests]
#    --------------------------- ------------ 11/16 [requests]
#    --------------------------- ------------ 11/16 [requests]
#    --------------------------- ------------ 11/16 [requests]
#    ------------------------------ --------- 12/16 [cffi]
#    ------------------------------ --------- 12/16 [cffi]
#    ------------------------------ --------- 12/16 [cffi]
#    ------------------------------ --------- 12/16 [cffi]
#    -------------------------------- ------- 13/16 [beautifulsoup4]
#    -------------------------------- ------- 13/16 [beautifulsoup4]
#    -------------------------------- ------- 13/16 [beautifulsoup4]
#    -------------------------------- ------- 13/16 [beautifulsoup4]
#    -------------------------------- ------- 13/16 [beautifulsoup4]
#    ----------------------------------- ---- 14/16 [curl_cffi]
#    ----------------------------------- ---- 14/16 [curl_cffi]
#    ----------------------------------- ---- 14/16 [curl_cffi]
#    ----------------------------------- ---- 14/16 [curl_cffi]
#    ----------------------------------- ---- 14/16 [curl_cffi]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ------------------------------------- -- 15/16 [yfinance]
#    ---------------------------------------- 16/16 [yfinance]
#
# Successfully installed beautifulsoup4-4.14.3 certifi-2026.1.4 cffi-2.0.0 charset_normalizer-3.4.4 curl_cffi-0.13.0 frozendict-2.4.7 idna-3.11 multitasking-0.0.12 peewee-3.19.0 protobuf-6.33.2 pycparser-2.23 requests-2.32.5 soupsieve-2.8.1 urllib3-2.6.3 websockets-15.0.1 yfinance-1.0

# %%
import pandas as pd
import yfinance as yf
import numpy as np
import datetime
from datetime import date, timedelta

today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1

d2 = date.today() - timedelta(days=768)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download("BTC-USD",
                   start=start_date,
                   end=end_date,
                   progress=False)

data["Date"] = data.index
data = data[['Date', 'Open', 'High', 'Low', 'Close', 'Volume']]

data.reset_index(drop=True, inplace=True)

# %%
print(data.head())
# Out:
# Price        Date          Open          High           Low         Close  \
# Ticker                  BTC-USD       BTC-USD       BTC-USD       BTC-USD
# 0      2023-12-02  38689.277344  39678.937500  38652.593750  39476.332031
# 1      2023-12-03  39472.207031  40135.605469  39298.164062  39978.390625
# 2      2023-12-04  39978.628906  42371.750000  39978.628906  41980.097656
# 3      2023-12-05  41986.265625  44408.664062  41421.148438  44080.648438
# 4      2023-12-06  44080.023438  44265.769531  43478.082031  43746.445312
#
# Price        Volume
# Ticker      BTC-USD
# 0       15534035612
# 1       15769696322
# 2       39856129827
# 3       36312154535
# 4       29909761586

# %%
print(data.tail())
# Out:
# Price        Date          Open          High           Low         Close  \
# Ticker                  BTC-USD       BTC-USD       BTC-USD       BTC-USD
# 763    2026-01-03  89945.054688  90679.570312  89328.070312  90603.187500
# 764    2026-01-04  90603.000000  91712.585938  90595.101562  91413.492188
# 765    2026-01-05  91414.625000  94762.070312  91414.625000  93882.554688
# 766    2026-01-06  93876.945312  94395.296875  91286.546875  93729.031250
# 767    2026-01-07  93727.468750  93738.789062  90601.804688  91308.054688
#
# Price        Volume
# Ticker      BTC-USD
# 763     20774828592
# 764     26770491368
# 765     53376407252
# 766     52430605257
# 767     43461295053

# %%
print(data.shape)
# Out:
# (768, 6)

# %%
import plotly.graph_objects as go

figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"],
                                        high=data["High"],
                                        low=data["Low"],
                                        close=data["Close"])])

figure.update_layout(title = "Bitcoin Price Analysis",
                     )
